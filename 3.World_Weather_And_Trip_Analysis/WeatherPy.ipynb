# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 634

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# %%sql

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}&units={units}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | waitangi
# Processing Record 2 of Set 1 | adamstown
# Processing Record 3 of Set 1 | tiksi
# Processing Record 4 of Set 1 | ta`u
# Processing Record 5 of Set 1 | chonchi
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | whitehorse
# Processing Record 8 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 9 of Set 1 | puerto natales
# Processing Record 10 of Set 1 | remire-montjoly
# Processing Record 11 of Set 1 | sungai penuh
# Processing Record 12 of Set 1 | barinas
# Processing Record 13 of Set 1 | flin flon
# Processing Record 14 of Set 1 | fallon
# Processing Record 15 of Set 1 | sagua la grande
# Processing Record 16 of Set 1 | yatou
# Processing Record 17 of Set 1 | toga village
# City not found. Skipping...
# Processing Record 18 of Set 1 | pangoa
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | iqaluit
# Processing Record 21 of Set 1 | colonia
# Processing Record 22 of Set 1 | papatowai
# Processing Record 23 of Set 1 | orlovskiy
# Processing Record 24 of Set 1 | grytviken
# Processing Record 25 of Set 1 | tsiombe
# Processing Record 26 of Set 1 | daru
# Processing Record 27 of Set 1 | pechora
# Processing Record 28 of Set 1 | tura
# Processing Record 29 of Set 1 | griffith
# Processing Record 30 of Set 1 | mejit
# Processing Record 31 of Set 1 | wailua homesteads
# Processing Record 32 of Set 1 | pathein
# Processing Record 33 of Set 1 | sao felix do xingu
# Processing Record 34 of Set 1 | udachny
# Processing Record 35 of Set 1 | port-aux-francais
# Processing Record 36 of Set 1 | taoudenni
# Processing Record 37 of Set 1 | aykol
# City not found. Skipping...
# Processing Record 38 of Set 1 | limon
# Processing Record 39 of Set 1 | yuzhno-kurilsk
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | egilsstadir
# Processing Record 42 of Set 1 | nizhniy odes
# Processing Record 43 of Set 1 | bei'an
# Processing Record 44 of Set 1 | iskateley
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | anadyr
# Processing Record 47 of Set 1 | hamilton
# Processing Record 48 of Set 1 | yellowknife
# Processing Record 49 of Set 1 | college
# Processing Record 50 of Set 1 | nguigmi
# Processing Record 0 of Set 2 | luderitz
# Processing Record 1 of Set 2 | west island
# Processing Record 2 of Set 2 | minas de marcona
# Processing Record 3 of Set 2 | olonkinbyen
# Processing Record 4 of Set 2 | touros
# Processing Record 5 of Set 2 | edinburgh of the seven seas
# Processing Record 6 of Set 2 | tromso
# Processing Record 7 of Set 2 | blackmans bay
# Processing Record 8 of Set 2 | aykhal
# Processing Record 9 of Set 2 | hilo
# Processing Record 10 of Set 2 | pocito
# Processing Record 11 of Set 2 | cartagena
# Processing Record 12 of Set 2 | flying fish cove
# Processing Record 13 of Set 2 | sisimiut
# Processing Record 14 of Set 2 | san antonio de pale
# Processing Record 15 of Set 2 | tolanaro
# Processing Record 16 of Set 2 | longyearbyen
# Processing Record 17 of Set 2 | brindisi
# Processing Record 18 of Set 2 | ushuaia
# Processing Record 19 of Set 2 | we
# City not found. Skipping...
# Processing Record 20 of Set 2 | mahina
# Processing Record 21 of Set 2 | bagasra
# Processing Record 22 of Set 2 | crane
# Processing Record 23 of Set 2 | port mathurin
# Processing Record 24 of Set 2 | oakdale
# Processing Record 25 of Set 2 | bilibino
# Processing Record 26 of Set 2 | port lincoln
# Processing Record 27 of Set 2 | santa cruz
# Processing Record 28 of Set 2 | inyonga
# Processing Record 29 of Set 2 | najran
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | vilyuysk
# Processing Record 32 of Set 2 | cabo san lucas
# Processing Record 33 of Set 2 | lakheri
# Processing Record 34 of Set 2 | huarmey
# Processing Record 35 of Set 2 | uturoa
# Processing Record 36 of Set 2 | chos malal
# Processing Record 37 of Set 2 | sumbe
# Processing Record 38 of Set 2 | isafjordur
# Processing Record 39 of Set 2 | shira
# Processing Record 40 of Set 2 | sarandi del yi
# Processing Record 41 of Set 2 | puerto ayora
# Processing Record 42 of Set 2 | afaahiti
# Processing Record 43 of Set 2 | ugoofaaru
# Processing Record 44 of Set 2 | invercargill
# Processing Record 45 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 46 of Set 2 | mogocha
# Processing Record 47 of Set 2 | wynyard
# Processing Record 48 of Set 2 | punta arenas
# Processing Record 49 of Set 2 | auki
# Processing Record 0 of Set 3 | phan rang-thap cham
# Processing Record 1 of Set 3 | lospalos
# Processing Record 2 of Set 3 | atafu village
# Processing Record 3 of Set 3 | oruro
# Processing Record 4 of Set 3 | bozuyuk
# Processing Record 5 of Set 3 | kismayo
# Processing Record 6 of Set 3 | pasni
# Processing Record 7 of Set 3 | al mayadin
# Processing Record 8 of Set 3 | caiaponia
# Processing Record 9 of Set 3 | ribeira grande
# Processing Record 10 of Set 3 | alofi
# Processing Record 11 of Set 3 | tofol
# Processing Record 12 of Set 3 | nantucket
# Processing Record 13 of Set 3 | bethel
# Processing Record 14 of Set 3 | argo
# Processing Record 15 of Set 3 | saint-philippe
# Processing Record 16 of Set 3 | congonhas
# Processing Record 17 of Set 3 | lorengau
# Processing Record 18 of Set 3 | saint-mandrier-sur-mer
# Processing Record 19 of Set 3 | bargara
# City not found. Skipping...
# Processing Record 20 of Set 3 | weno
# Processing Record 21 of Set 3 | amarillo
# Processing Record 22 of Set 3 | noyabrsk
# Processing Record 23 of Set 3 | carbonear
# Processing Record 24 of Set 3 | san andres
# Processing Record 25 of Set 3 | thunder bay
# Processing Record 26 of Set 3 | la passe
# Processing Record 27 of Set 3 | tralee
# Processing Record 28 of Set 3 | fortuna
# Processing Record 29 of Set 3 | saint-joseph
# Processing Record 30 of Set 3 | coquimbo
# Processing Record 31 of Set 3 | makurazaki
# Processing Record 32 of Set 3 | thompson
# Processing Record 33 of Set 3 | mount pearl
# Processing Record 34 of Set 3 | ivdel'
# Processing Record 35 of Set 3 | badger
# Processing Record 36 of Set 3 | malard
# Processing Record 37 of Set 3 | hawaiian paradise park
# Processing Record 38 of Set 3 | caleta de carquin
# Processing Record 39 of Set 3 | greymouth
# Processing Record 40 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 41 of Set 3 | shuangjiang
# Processing Record 42 of Set 3 | cidreira
# Processing Record 43 of Set 3 | port alfred
# Processing Record 44 of Set 3 | nouadhibou
# Processing Record 45 of Set 3 | stanley
# Processing Record 46 of Set 3 | sorsk
# Processing Record 47 of Set 3 | hood river
# Processing Record 48 of Set 3 | waingapu
# Processing Record 49 of Set 3 | kapa'a
# Processing Record 0 of Set 4 | baglung
# Processing Record 1 of Set 4 | lerwick
# Processing Record 2 of Set 4 | lihue
# Processing Record 3 of Set 4 | enewetak
# Processing Record 4 of Set 4 | mulchen
# Processing Record 5 of Set 4 | vorgashor
# Processing Record 6 of Set 4 | san vicente de canete
# Processing Record 7 of Set 4 | lembar
# City not found. Skipping...
# Processing Record 8 of Set 4 | saipan
# Processing Record 9 of Set 4 | jaumave
# Processing Record 10 of Set 4 | manokwari
# Processing Record 11 of Set 4 | siwa oasis
# Processing Record 12 of Set 4 | jamestown
# Processing Record 13 of Set 4 | mariental
# Processing Record 14 of Set 4 | namibe
# Processing Record 15 of Set 4 | broken hill
# Processing Record 16 of Set 4 | baiyin
# Processing Record 17 of Set 4 | kavaratti
# Processing Record 18 of Set 4 | plymouth
# Processing Record 19 of Set 4 | mount isa
# Processing Record 20 of Set 4 | talnakh
# Processing Record 21 of Set 4 | sibbo
# Processing Record 22 of Set 4 | le morne-rouge
# Processing Record 23 of Set 4 | el grao
# Processing Record 24 of Set 4 | okhotsk
# Processing Record 25 of Set 4 | jhanjharpur
# Processing Record 26 of Set 4 | santa croce camerina
# Processing Record 27 of Set 4 | neryungri
# Processing Record 28 of Set 4 | gadzhiyevo
# Processing Record 29 of Set 4 | mezhdurechenskiy
# Processing Record 30 of Set 4 | berdigestyakh
# Processing Record 31 of Set 4 | pemalang
# Processing Record 32 of Set 4 | suntar
# Processing Record 33 of Set 4 | pyt-yakh
# Processing Record 34 of Set 4 | viedma
# Processing Record 35 of Set 4 | lagoa
# Processing Record 36 of Set 4 | lompoc
# Processing Record 37 of Set 4 | sonsorol village
# City not found. Skipping...
# Processing Record 38 of Set 4 | richards bay
# Processing Record 39 of Set 4 | trochtelfingen
# Processing Record 40 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 41 of Set 4 | berwick-upon-tweed
# Processing Record 42 of Set 4 | bamboo flat
# Processing Record 43 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 44 of Set 4 | porto novo
# Processing Record 45 of Set 4 | tinajo
# Processing Record 46 of Set 4 | taiohae
# City not found. Skipping...
# Processing Record 47 of Set 4 | hargeysa
# Processing Record 48 of Set 4 | mocimboa
# Processing Record 49 of Set 4 | upington
# Processing Record 0 of Set 5 | hasaki
# Processing Record 1 of Set 5 | rossford
# Processing Record 2 of Set 5 | charkhari
# Processing Record 3 of Set 5 | fale old settlement
# Processing Record 4 of Set 5 | kultali
# City not found. Skipping...
# Processing Record 5 of Set 5 | hermanus
# Processing Record 6 of Set 5 | tobruk
# Processing Record 7 of Set 5 | cody
# Processing Record 8 of Set 5 | lebu
# Processing Record 9 of Set 5 | turpan
# Processing Record 10 of Set 5 | marsassoum
# Processing Record 11 of Set 5 | magadan
# Processing Record 12 of Set 5 | gutao
# Processing Record 13 of Set 5 | ouarzazat
# Processing Record 14 of Set 5 | murmashi
# Processing Record 15 of Set 5 | plastun
# Processing Record 16 of Set 5 | tindouf
# Processing Record 17 of Set 5 | al-`ula
# City not found. Skipping...
# Processing Record 18 of Set 5 | nar'yan-mar
# Processing Record 19 of Set 5 | vuktyl
# Processing Record 20 of Set 5 | chyorny yar
# Processing Record 21 of Set 5 | kerikeri
# Processing Record 22 of Set 5 | uaboe
# City not found. Skipping...
# Processing Record 23 of Set 5 | st. john's
# Processing Record 24 of Set 5 | dalnegorsk
# Processing Record 25 of Set 5 | kolonia town
# Processing Record 26 of Set 5 | le port
# Processing Record 27 of Set 5 | newman
# Processing Record 28 of Set 5 | san juan de miraflores
# Processing Record 29 of Set 5 | mugia
# Processing Record 30 of Set 5 | tshabong
# Processing Record 31 of Set 5 | puerto baquerizo moreno
# Processing Record 32 of Set 5 | agat village
# Processing Record 33 of Set 5 | souillac
# Processing Record 34 of Set 5 | ardakan
# Processing Record 35 of Set 5 | dunedin
# Processing Record 36 of Set 5 | tazovsky
# Processing Record 37 of Set 5 | ndola
# Processing Record 38 of Set 5 | setti fatma
# City not found. Skipping...
# Processing Record 39 of Set 5 | la'ie
# Processing Record 40 of Set 5 | sitka
# Processing Record 41 of Set 5 | mata-utu
# Processing Record 42 of Set 5 | erseke
# Processing Record 43 of Set 5 | vernon
# Processing Record 44 of Set 5 | cobija
# Processing Record 45 of Set 5 | nadym
# Processing Record 46 of Set 5 | ola
# Processing Record 47 of Set 5 | waddan
# Processing Record 48 of Set 5 | severo-yeniseyskiy
# Processing Record 49 of Set 5 | kodinsk
# Processing Record 0 of Set 6 | arraial do cabo
# Processing Record 1 of Set 6 | palikir - national government center
# Processing Record 2 of Set 6 | cuito
# Processing Record 3 of Set 6 | ust-nera
# Processing Record 4 of Set 6 | hue
# Processing Record 5 of Set 6 | meizhou
# Processing Record 6 of Set 6 | nabire
# Processing Record 7 of Set 6 | margaret river
# Processing Record 8 of Set 6 | jining
# Processing Record 9 of Set 6 | jalqani
# Processing Record 10 of Set 6 | lata
# Processing Record 11 of Set 6 | khandyga
# Processing Record 12 of Set 6 | ketchikan
# Processing Record 13 of Set 6 | antalaha
# Processing Record 14 of Set 6 | hotan
# Processing Record 15 of Set 6 | odlabari
# Processing Record 16 of Set 6 | illizi
# Processing Record 17 of Set 6 | nombre de dios
# Processing Record 18 of Set 6 | palmer
# Processing Record 19 of Set 6 | port elizabeth
# Processing Record 20 of Set 6 | sidney
# Processing Record 21 of Set 6 | youghal
# Processing Record 22 of Set 6 | smithers
# Processing Record 23 of Set 6 | arafat
# Processing Record 24 of Set 6 | espargos
# City not found. Skipping...
# Processing Record 25 of Set 6 | talcahuano
# Processing Record 26 of Set 6 | cova figueira
# Processing Record 27 of Set 6 | hadibu
# Processing Record 28 of Set 6 | qaqortoq
# Processing Record 29 of Set 6 | hauterive
# Processing Record 30 of Set 6 | prado
# Processing Record 31 of Set 6 | kongolo
# Processing Record 32 of Set 6 | saint-pierre
# Processing Record 33 of Set 6 | martapura
# Processing Record 34 of Set 6 | greenwood
# Processing Record 35 of Set 6 | chibougamau
# Processing Record 36 of Set 6 | bridgewater
# Processing Record 37 of Set 6 | dhidhdhoo
# Processing Record 38 of Set 6 | yelizovo
# Processing Record 39 of Set 6 | howard springs
# Processing Record 40 of Set 6 | yeniseysk
# Processing Record 41 of Set 6 | alcamo
# Processing Record 42 of Set 6 | saugor
# Processing Record 43 of Set 6 | usogorsk
# Processing Record 44 of Set 6 | utrik
# Processing Record 45 of Set 6 | villa juarez
# Processing Record 46 of Set 6 | grassano
# Processing Record 47 of Set 6 | baruun-urt
# Processing Record 48 of Set 6 | ferkessedougou
# Processing Record 49 of Set 6 | sabang
# Processing Record 0 of Set 7 | camalu
# Processing Record 1 of Set 7 | grantsville
# Processing Record 2 of Set 7 | dabakala
# Processing Record 3 of Set 7 | laikit, laikit ii (dimembe)
# Processing Record 4 of Set 7 | micheweni
# Processing Record 5 of Set 7 | urumqi
# Processing Record 6 of Set 7 | pilar
# Processing Record 7 of Set 7 | mamuju
# Processing Record 8 of Set 7 | falam
# Processing Record 9 of Set 7 | poronaysk
# Processing Record 10 of Set 7 | karratha
# Processing Record 11 of Set 7 | cargados carajos
# City not found. Skipping...
# Processing Record 12 of Set 7 | kosikha
# Processing Record 13 of Set 7 | palembang
# Processing Record 14 of Set 7 | okha
# Processing Record 15 of Set 7 | happy valley-goose bay
# Processing Record 16 of Set 7 | sao joao da barra
# Processing Record 17 of Set 7 | nemuro
# Processing Record 18 of Set 7 | kingston
# Processing Record 19 of Set 7 | puerto leguizamo
# Processing Record 20 of Set 7 | mezhdurechensk
# Processing Record 21 of Set 7 | byelaazyorsk
# Processing Record 22 of Set 7 | puerto colombia
# Processing Record 23 of Set 7 | labrador city
# Processing Record 24 of Set 7 | kailua-kona
# Processing Record 25 of Set 7 | yampil'
# Processing Record 26 of Set 7 | rozhyshche
# Processing Record 27 of Set 7 | ghazni
# Processing Record 28 of Set 7 | crucecita
# Processing Record 29 of Set 7 | fort st. john
# Processing Record 30 of Set 7 | gremyachevo
# Processing Record 31 of Set 7 | lycksele
# Processing Record 32 of Set 7 | timimoun
# Processing Record 33 of Set 7 | mar del plata
# Processing Record 34 of Set 7 | murzuq
# Processing Record 35 of Set 7 | bardai
# Processing Record 36 of Set 7 | klyuchi
# Processing Record 37 of Set 7 | boa vista
# Processing Record 38 of Set 7 | oranjemund
# Processing Record 39 of Set 7 | rio grande
# Processing Record 40 of Set 7 | pingzhuang
# Processing Record 41 of Set 7 | hanzhong
# Processing Record 42 of Set 7 | haskovo
# Processing Record 43 of Set 7 | tehran
# Processing Record 44 of Set 7 | misratah
# Processing Record 45 of Set 7 | cape coast
# Processing Record 46 of Set 7 | amungan
# Processing Record 47 of Set 7 | bar
# Processing Record 48 of Set 7 | vilyuchinsk
# Processing Record 49 of Set 7 | ijuw
# City not found. Skipping...
# Processing Record 0 of Set 8 | sitia
# Processing Record 1 of Set 8 | sumbawa besar
# Processing Record 2 of Set 8 | rongelap
# Processing Record 3 of Set 8 | wanning
# Processing Record 4 of Set 8 | chahar burj
# Processing Record 5 of Set 8 | san patricio
# Processing Record 6 of Set 8 | kodiak
# Processing Record 7 of Set 8 | laguna
# Processing Record 8 of Set 8 | robertsport
# Processing Record 9 of Set 8 | yorkton
# Processing Record 10 of Set 8 | kayyerkan
# Processing Record 11 of Set 8 | constantia
# Processing Record 12 of Set 8 | dudinka
# Processing Record 13 of Set 8 | guerrero negro
# Processing Record 14 of Set 8 | khurja
# Processing Record 15 of Set 8 | archangelos
# Processing Record 16 of Set 8 | aracati
# Processing Record 17 of Set 8 | aasiaat
# Processing Record 18 of Set 8 | yashan
# Processing Record 19 of Set 8 | orda
# Processing Record 20 of Set 8 | haiku-pauwela
# Processing Record 21 of Set 8 | tokar
# Processing Record 22 of Set 8 | gopalpur
# Processing Record 23 of Set 8 | horta
# Processing Record 24 of Set 8 | yangor
# City not found. Skipping...
# Processing Record 25 of Set 8 | vallegrande
# Processing Record 26 of Set 8 | fort-shevchenko
# Processing Record 27 of Set 8 | carnarvon
# Processing Record 28 of Set 8 | upata
# Processing Record 29 of Set 8 | aweil
# Processing Record 30 of Set 8 | taro
# Processing Record 31 of Set 8 | new norfolk
# Processing Record 32 of Set 8 | mili
# Processing Record 33 of Set 8 | tommot
# Processing Record 34 of Set 8 | sretensk
# Processing Record 35 of Set 8 | kruisfontein
# Processing Record 36 of Set 8 | nova sintra
# Processing Record 37 of Set 8 | el hadjar
# Processing Record 38 of Set 8 | mutoko
# Processing Record 39 of Set 8 | laghouat
# Processing Record 40 of Set 8 | queenstown
# Processing Record 41 of Set 8 | betio village
# Processing Record 42 of Set 8 | midvagur
# Processing Record 43 of Set 8 | quellon
# Processing Record 44 of Set 8 | sirte
# Processing Record 45 of Set 8 | mehran
# Processing Record 46 of Set 8 | mpanda
# Processing Record 47 of Set 8 | juan griego
# Processing Record 48 of Set 8 | jatiroto
# Processing Record 49 of Set 8 | nuuk
# Processing Record 0 of Set 9 | broome
# Processing Record 1 of Set 9 | barcelos
# Processing Record 2 of Set 9 | inhuma
# Processing Record 3 of Set 9 | luanda
# Processing Record 4 of Set 9 | bonthe
# Processing Record 5 of Set 9 | mahibadhoo
# Processing Record 6 of Set 9 | liwale
# Processing Record 7 of Set 9 | strezhevoy
# Processing Record 8 of Set 9 | penhalonga
# Processing Record 9 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 10 of Set 9 | al khawr
# Processing Record 11 of Set 9 | tanjung pandan
# Processing Record 12 of Set 9 | la ligua
# Processing Record 13 of Set 9 | espinosa
# Processing Record 14 of Set 9 | north platte
# Processing Record 15 of Set 9 | ipatovo
# Processing Record 16 of Set 9 | malango
# Processing Record 17 of Set 9 | baoying
# Processing Record 18 of Set 9 | acajutla
# Processing Record 19 of Set 9 | tonosho
# Processing Record 20 of Set 9 | ouellah
# City not found. Skipping...
# Processing Record 21 of Set 9 | manali
# Processing Record 22 of Set 9 | bubaque
# Processing Record 23 of Set 9 | nizhnevartovsk
# Processing Record 24 of Set 9 | westport
# Processing Record 25 of Set 9 | magalia
# Processing Record 26 of Set 9 | rawson
# Processing Record 27 of Set 9 | biryusinsk
# Processing Record 28 of Set 9 | noumea
# Processing Record 29 of Set 9 | mombetsu
# Processing Record 30 of Set 9 | jalai nur
# Processing Record 31 of Set 9 | ruidoso
# Processing Record 32 of Set 9 | bayji
# Processing Record 33 of Set 9 | nynashamn
# Processing Record 34 of Set 9 | lisala
# Processing Record 35 of Set 9 | aguas belas
# Processing Record 36 of Set 9 | arawa
# Processing Record 37 of Set 9 | arica
# Processing Record 38 of Set 9 | fort bragg
# Processing Record 39 of Set 9 | gangoh
# Processing Record 40 of Set 9 | villa gesell
# Processing Record 41 of Set 9 | nehe
# Processing Record 42 of Set 9 | shakhun'ya
# Processing Record 43 of Set 9 | volosovo
# Processing Record 44 of Set 9 | cole harbour
# Processing Record 45 of Set 9 | cambria
# Processing Record 46 of Set 9 | koungheul
# Processing Record 47 of Set 9 | ploudalmezeau
# Processing Record 48 of Set 9 | wakkanai
# Processing Record 49 of Set 9 | khovd
# Processing Record 0 of Set 10 | west bay
# Processing Record 1 of Set 10 | umm kaddadah
# Processing Record 2 of Set 10 | pacific grove
# Processing Record 3 of Set 10 | kotido
# Processing Record 4 of Set 10 | tsengel
# Processing Record 5 of Set 10 | quimili
# Processing Record 6 of Set 10 | justiniano posse
# Processing Record 7 of Set 10 | anna regina
# Processing Record 8 of Set 10 | sibiti
# Processing Record 9 of Set 10 | san pedro pochutla
# Processing Record 10 of Set 10 | grand island
# Processing Record 11 of Set 10 | ust'-kut
# Processing Record 12 of Set 10 | sydney mines
# Processing Record 13 of Set 10 | bandar lampung
# Processing Record 14 of Set 10 | akureyri
# Processing Record 15 of Set 10 | recani
# Processing Record 16 of Set 10 | pyapon
# Processing Record 17 of Set 10 | northam
# Processing Record 18 of Set 10 | hayma'
# City not found. Skipping...
# Processing Record 19 of Set 10 | clearwater
# Processing Record 20 of Set 10 | mokhsogollokh
# Processing Record 21 of Set 10 | kyshtovka
# Processing Record 22 of Set 10 | goundam
# Processing Record 23 of Set 10 | cockburn town
# Processing Record 24 of Set 10 | nambucca heads
# Processing Record 25 of Set 10 | al kharj
# Processing Record 26 of Set 10 | mubende
# Processing Record 27 of Set 10 | tadine
# Processing Record 28 of Set 10 | dryden
# Processing Record 29 of Set 10 | portland
# Processing Record 30 of Set 10 | loen
# Processing Record 31 of Set 10 | vila velha
# Processing Record 32 of Set 10 | oum hadjer
# Processing Record 33 of Set 10 | mildura
# Processing Record 34 of Set 10 | abra pampa
# Processing Record 35 of Set 10 | jaguariaiva
# Processing Record 36 of Set 10 | manvi
# Processing Record 37 of Set 10 | razole
# Processing Record 38 of Set 10 | sandnessjoen
# Processing Record 39 of Set 10 | cayiralan
# Processing Record 40 of Set 10 | coahuayana de hidalgo
# Processing Record 41 of Set 10 | unecha
# Processing Record 42 of Set 10 | freeport
# Processing Record 43 of Set 10 | tanda
# Processing Record 44 of Set 10 | soto la marina
# Processing Record 45 of Set 10 | chernigovka
# Processing Record 46 of Set 10 | kone
# Processing Record 47 of Set 10 | santa vitoria do palmar
# Processing Record 48 of Set 10 | tranovaho
# City not found. Skipping...
# Processing Record 49 of Set 10 | vorkuta
# Processing Record 0 of Set 11 | oradea
# Processing Record 1 of Set 11 | changzhi
# Processing Record 2 of Set 11 | timmins
# Processing Record 3 of Set 11 | voronovytsya
# Processing Record 4 of Set 11 | maceio
# Processing Record 5 of Set 11 | santa ana
# Processing Record 6 of Set 11 | kilindoni
# Processing Record 7 of Set 11 | pacocha
# Processing Record 8 of Set 11 | carutapera
# Processing Record 9 of Set 11 | smara
# Processing Record 10 of Set 11 | dalaba
# Processing Record 11 of Set 11 | jakobstad
# Processing Record 12 of Set 11 | hobyo
# Processing Record 13 of Set 11 | ilulissat
# Processing Record 14 of Set 11 | katsuura
# Processing Record 15 of Set 11 | menongue
# Processing Record 16 of Set 11 | polyarnyy
# Processing Record 17 of Set 11 | port isabel
# Processing Record 18 of Set 11 | fernley
# Processing Record 19 of Set 11 | bata
# Processing Record 20 of Set 11 | keflavik
# Processing Record 21 of Set 11 | saudarkrokur
# Processing Record 22 of Set 11 | nuku'alofa
# Processing Record 23 of Set 11 | quincy
# Processing Record 24 of Set 11 | laojunmiao
# Processing Record 25 of Set 11 | pontianak
# Processing Record 26 of Set 11 | kotabumi
# Processing Record 27 of Set 11 | edson
# Processing Record 28 of Set 11 | kabare
# Processing Record 29 of Set 11 | zaragoza
# Processing Record 30 of Set 11 | sterling
# Processing Record 31 of Set 11 | san julian
# Processing Record 32 of Set 11 | susuman
# Processing Record 33 of Set 11 | faya-largeau
# Processing Record 34 of Set 11 | bogo
# Processing Record 35 of Set 11 | praia da vitoria
# Processing Record 36 of Set 11 | adrar
# Processing Record 37 of Set 11 | brookings
# Processing Record 38 of Set 11 | kalmunai
# Processing Record 39 of Set 11 | coaticook
# Processing Record 40 of Set 11 | bikenibeu village
# Processing Record 41 of Set 11 | kili
# Processing Record 42 of Set 11 | buala
# Processing Record 43 of Set 11 | sofifi
# City not found. Skipping...
# Processing Record 44 of Set 11 | kasempa
# Processing Record 45 of Set 11 | chiaravalle
# Processing Record 46 of Set 11 | nadi
# Processing Record 47 of Set 11 | kiunga
# Processing Record 48 of Set 11 | geraldton
# Processing Record 49 of Set 11 | kattaqo'rg'on shahri
# City not found. Skipping...
# Processing Record 0 of Set 12 | fuvahmulah
# City not found. Skipping...
# Processing Record 1 of Set 12 | san jose del guaviare
# Processing Record 2 of Set 12 | makarov
# Processing Record 3 of Set 12 | tanjung selor
# City not found. Skipping...
# Processing Record 4 of Set 12 | noosa heads
# Processing Record 5 of Set 12 | albertina
# Processing Record 6 of Set 12 | olovyannaya
# Processing Record 7 of Set 12 | cherdyn'
# Processing Record 8 of Set 12 | nytva
# Processing Record 9 of Set 12 | praia
# Processing Record 10 of Set 12 | east london
# Processing Record 11 of Set 12 | walvis bay
# Processing Record 12 of Set 12 | sortavala
# Processing Record 13 of Set 12 | kashgar
# Processing Record 14 of Set 12 | eastham
# Processing Record 15 of Set 12 | maslyanino
# Processing Record 16 of Set 12 | mount gambier
# Processing Record 17 of Set 12 | kill devil hills
# Processing Record 18 of Set 12 | hovd
# Processing Record 19 of Set 12 | ryotsu-minato
# Processing Record 20 of Set 12 | carmo do rio claro
# Processing Record 21 of Set 12 | berezovyy
# Processing Record 22 of Set 12 | selfoss
# Processing Record 23 of Set 12 | chegdomyn
# Processing Record 24 of Set 12 | gemena
# Processing Record 25 of Set 12 | darwha
# Processing Record 26 of Set 12 | yaren
# Processing Record 27 of Set 12 | jeddah
# Processing Record 28 of Set 12 | gamay
# Processing Record 29 of Set 12 | yeppoon
# Processing Record 30 of Set 12 | banfora
# Processing Record 31 of Set 12 | holualoa
# Processing Record 32 of Set 12 | wahpeton
# Processing Record 33 of Set 12 | howrah
# Processing Record 34 of Set 12 | woods creek
# Processing Record 35 of Set 12 | arkhangel'sk
# Processing Record 36 of Set 12 | shiloh
# Processing Record 37 of Set 12 | buncrana
# Processing Record 38 of Set 12 | papao
# Processing Record 39 of Set 12 | eydhafushi
# Processing Record 40 of Set 12 | mesquite
# Processing Record 41 of Set 12 | moroni
# Processing Record 42 of Set 12 | limulunga
# Processing Record 43 of Set 12 | hell-ville
# Processing Record 44 of Set 12 | kudahuvadhoo
# Processing Record 45 of Set 12 | chanute
# Processing Record 46 of Set 12 | nay pyi taw
# Processing Record 47 of Set 12 | figeac
# Processing Record 48 of Set 12 | edd
# Processing Record 49 of Set 12 | oytal
# Processing Record 0 of Set 13 | el triunfo
# Processing Record 1 of Set 13 | wellington
# Processing Record 2 of Set 13 | harstad
# Processing Record 3 of Set 13 | tayshet
# Processing Record 4 of Set 13 | richfield
# Processing Record 5 of Set 13 | ocean city
# Processing Record 6 of Set 13 | kingscliff
# Processing Record 7 of Set 13 | tera
# Processing Record 8 of Set 13 | hope
# Processing Record 9 of Set 13 | badiyah
# Processing Record 10 of Set 13 | dzhubga
# Processing Record 11 of Set 13 | san rafael
# Processing Record 12 of Set 13 | ribadesella
# Processing Record 13 of Set 13 | coyhaique
# Processing Record 14 of Set 13 | inhambane
# Processing Record 15 of Set 13 | revda
# Processing Record 16 of Set 13 | slavgorod
# Processing Record 17 of Set 13 | brokopondo
# Processing Record 18 of Set 13 | saynshand
# Processing Record 19 of Set 13 | kwekwe
# Processing Record 20 of Set 13 | kintampo
# Processing Record 21 of Set 13 | live oak
# Processing Record 22 of Set 13 | champerico
# Processing Record 23 of Set 13 | ankang
# Processing Record 24 of Set 13 | ataq
# Processing Record 25 of Set 13 | costa calma
# City not found. Skipping...
# Processing Record 26 of Set 13 | kotel'nich
# Processing Record 27 of Set 13 | vadso
# Processing Record 28 of Set 13 | ixtapa
# Processing Record 29 of Set 13 | entre rios
# Processing Record 30 of Set 13 | poiana teiului
# Processing Record 31 of Set 13 | belleville
# Processing Record 32 of Set 13 | masterton
# Processing Record 33 of Set 13 | zaozersk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
from pprint import pprint
pprint(city_data[0])
# Out:
# {'City': 'waitangi',
#  'Cloudiness': 46,
#  'Country': 'NZ',
#  'Date': 1718828878,
#  'Humidity': 88,
#  'Lat': -43.9535,
#  'Lng': -176.5597,
#  'Max Temp': 9.34,
#  'Wind Speed': 1.79}

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          606
# Lat           606
# Lng           606
# Max Temp      606
# Humidity      606
# Cloudiness    606
# Wind Speed    606
# Country       606
# Date          606
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   waitangi -43.9535 -176.5597      9.34        88          46        1.79
# 1  adamstown -25.0660 -130.1015     22.05        74           0        8.43
# 2      tiksi  71.6872  128.8694      2.16        83          94        1.53
# 3       ta`u -14.2336 -169.5144     27.32        81          40        7.79
# 4    chonchi -42.6128  -73.8092      6.73        83          78        1.56
#
#   Country        Date
# 0      NZ  1718828878
# 1      PN  1718828878
# 2      RU  1718828878
# 3      AS  1718828879
# 4      CL  1718828879

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         waitangi -43.9535 -176.5597      9.34        88          46
# 1        adamstown -25.0660 -130.1015     22.05        74           0
# 2            tiksi  71.6872  128.8694      2.16        83          94
# 3             ta`u -14.2336 -169.5144     27.32        81          40
# 4          chonchi -42.6128  -73.8092      6.73        83          78
#
#          Wind Speed Country        Date
# City_ID
# 0              1.79      NZ  1718828878
# 1              8.43      PN  1718828878
# 2              1.53      RU  1718828878
# 3              7.79      AS  1718828879
# 4              1.56      CL  1718828879

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
import datetime as dt
lat = city_data_df['Lat']
temp = city_data_df['Max Temp']
date_first = city_data_df['Date'].iloc[0]
utc_date = dt.datetime.utcfromtimestamp(date_first)

plt.figure(figsize=(10, 8))
plt.scatter(lat, temp, edgecolor='white', linewidth=1, color='blue', s=100, alpha= 0.7)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")
plt.title(f"City Max Temperature VS Temperature ({utc_date.strftime('%Y-%m-%d')})")

# Incorporate the other graph properties
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
humidity = city_data_df['Humidity']

# Incorporate the other graph properties
plt.figure(figsize=(10, 8))
plt.scatter(lat, humidity, edgecolor='white', linewidth=1, color='blue', s=100, alpha= 0.7)
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.title(f"City Max Temperature VS Humidity ({utc_date.strftime('%Y-%m-%d')})")

plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
cloudiness = city_data_df['Cloudiness']

# Incorporate the other graph properties
plt.figure(figsize=(10, 8))
plt.scatter(lat, cloudiness, edgecolor='white', linewidth=1, color='blue', s=100, alpha= 0.7)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.title(f"City Max Temperature VS Cloudiness ({utc_date.strftime('%Y-%m-%d')})")

plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
wind_speed = city_data_df['Wind Speed']

# Incorporate the other graph properties
plt.figure(figsize=(10, 8))
plt.scatter(lat, wind_speed, edgecolor='white', linewidth=1, color='blue', s=100, alpha= 0.7)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(m/s)")
plt.title(f"City Max Temperature VS Wind Speed ({utc_date.strftime('%Y-%m-%d')})")

plt.grid(True)

# Save the figure 
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def create_linear_regression_plot(x, y, x_label, y_label):
    """
    Create a scatter plot with a linear regression line and annotate the regression equation.
    
    Parameters:
    - x: array-like, the x data
    - y: array-like, the y data
    - x_label: str, the label for the x-axis
    - y_label: str, the label for the y-axis
    - title: str, the title of the plot
    """

    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

    # Create regression line values
    regress_values = x * slope + intercept
    line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

    # Plot data and regression line
    plt.figure(figsize=(10, 8))
    plt.scatter(x, y, edgecolor='white', linewidth=1, color='blue', s=100)
    plt.plot(x, regress_values, 'r-', label="Regression Line")

    # Add labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(f"The r-value is: {rvalue}", loc="left")

    # Add regression line equation as annotation
    plt.annotate(line_eq, xy=(x.mean(), regress_values.mean()), xytext=(x.mean() + 10, regress_values.mean() + 10),
                 textcoords='data', fontsize=12, color='red',
                 bbox=dict(boxstyle="round,pad=0.3", edgecolor='red', facecolor='white'),
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3", color='red'))

    # Add legend
    plt.legend(loc="best")

    # Show plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df.loc[:, 'Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2                  tiksi  71.6872  128.8694      2.16        83          94
# 6             whitehorse  60.7161 -135.0538     22.28        29          20
# 8        remire-montjoly   4.9167  -52.2667     31.02        66          20
# 10               barinas   8.6226  -70.2075     28.96        71          58
# 11             flin flon  54.7682 -101.8650     16.91        36          75
#
#          Wind Speed Country        Date
# City_ID
# 2              1.53      RU  1718828878
# 6              3.60      CA  1718828880
# 8              3.60      GF  1718828880
# 10             3.23      VE  1718828836
# 11             8.23      CA  1718828881

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df.loc[:, 'Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         waitangi -43.9535 -176.5597      9.34        88          46
# 1        adamstown -25.0660 -130.1015     22.05        74           0
# 3             ta`u -14.2336 -169.5144     27.32        81          40
# 4          chonchi -42.6128  -73.8092      6.73        83          78
# 5        hithadhoo  -0.6000   73.0833     28.42        71          68
#
#          Wind Speed Country        Date
# City_ID
# 0              1.79      NZ  1718828878
# 1              8.43      PN  1718828878
# 3              7.79      AS  1718828879
# 4              1.56      CL  1718828879
# 5              2.54      MV  1718828879

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x = northern_hemi_df['Lat'].values
y = northern_hemi_df['Max Temp'].values
create_linear_regression_plot(x, y, x_label="Latitude", y_label="Max Temp")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       2 x = northern_hemi_df['Lat'].values
#       3 y = northern_hemi_df['Max Temp'].values
# ----> 4 slope, intercept, rvalue, pvalue, stderr = create_linear_regression_plot(x, y, x_label="Latitude", y_label="Max Temp")
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
# Linear regression on Southern Hemisphere
x = southern_hemi_df['Lat'].values
y = southern_hemi_df['Max Temp'].values
create_linear_regression_plot(x, y, x_label="Latitude", y_label="Max Temp")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 x = southern_hemi_df['Lat'].values
#       3 y = southern_hemi_df['Max Temp'].values
# ----> 4 slope, intercept, rvalue, pvalue, stderr = create_linear_regression_plot(x, y, x_label="Latitude", y_label="Max Temp")
#
# TypeError: cannot unpack non-iterable NoneType object

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
#
# ### Analysis:
#
# 1. These two scatter plots and their regression lines reveal the impact of latitude on maximum temperature.
#
# - The first scatter plot and its regression line show that cities at higher latitudes generally have lower maximum temperatures.
# - The second scatter plot and its regression line show that cities at higher latitudes in the Southern Hemisphere (closer to the equator) generally have higher maximum temperatures.
#
# 2. Comparison of slopes
# - Northern Hemisphere: A negative slope (-0.35) indicates that as you move from the equator towards the North Pole, temperatures decrease.
# - Southern Hemisphere: A positive slope (0.47) indicates that as you move from the South Pole towards the equator, temperatures increase.
#
# 3. The R value for the Northern Hemisphere is -0.7255, and the R value for the Southern Hemisphere is 0.8175, both indicating that the model has a good fit to the data.
#
# ### Conclusion:
#
# - The relationship between latitude and maximum temperature is reasonable in terms of geography and climatology because regions closer to the equator typically have higher temperatures, while those near the North or South Poles have lower temperatures.
#
# - The contrast between hemispheres further proves the significant impact of geographic latitude on temperature, an effect consistent globally.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df['Lat'].values
y = northern_hemi_df['Humidity'].values
create_linear_regression_plot(x, y, x_label="Latitude", y_label="Humidity")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       2 x = northern_hemi_df['Lat'].values
#       3 y = northern_hemi_df['Humidity'].values
# ----> 4 slope, intercept, rvalue, pvalue, stderr = create_linear_regression_plot(x, y, x_label="Latitude", y_label="Humidity")
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
# Southern Hemisphere
x = southern_hemi_df['Lat'].values
y = southern_hemi_df['Humidity'].values
create_linear_regression_plot(x, y, x_label="Latitude", y_label="Humidity")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       2 x = southern_hemi_df['Lat'].values
#       3 y = southern_hemi_df['Humidity'].values
# ----> 4 slope, intercept, rvalue, pvalue, stderr = create_linear_regression_plot(x, y, x_label="Latitude", y_label="Humidity")
#
# TypeError: cannot unpack non-iterable NoneType object

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
#
# ### Analysis
#
# 1. The impact of latitude on humidity is weak:
#
#     - In the Northern Hemisphere, the slope is positive (0.16), indicating a slight upward trend in humidity with increasing latitude, but the relationship is very weak.
#     - In the Southern Hemisphere, the slope is even smaller (0.02), almost negligible, suggesting that latitude has an even less significant effect on humidity.
#
# 2. Very low correlation: The r values for both hemispheres are very low, 0.13 and 0.01 respectively, indicating that there is almost no linear correlation between latitude and humidity in either hemisphere.
#
# 3. High data dispersion: The scatter plots in both graphs are highly dispersed without any obvious linear trend, further demonstrating that the relationship between latitude and humidity is not significant.
#
# ### Conclusion
#
# Overall, both graphs indicate that whether in the Northern or Southern Hemisphere, the influence of latitude on humidity is very weak and almost non-existent. This suggests that humidity may be influenced by other more complex climatic factors and geographical features rather than just changes in latitude alone. When analyzing humidity distribution, more variables and factors should be considered instead of focusing solely on latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df['Lat'].values
y = northern_hemi_df['Cloudiness'].values
create_linear_regression_plot(x, y, x_label="Latitude", y_label="Cloudiness")

# %%
# Southern Hemisphere
x = southern_hemi_df['Lat'].values
y = southern_hemi_df['Cloudiness'].values
slope, intercept, rvalue, pvalue, stderr = create_linear_regression_plot(x, y, x_label="Latitude", y_label="Cloudiness")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       2 x = southern_hemi_df['Lat'].values
#       3 y = southern_hemi_df['Cloudiness'].values
# ----> 4 slope, intercept, rvalue, pvalue, stderr = create_linear_regression_plot(x, y, x_label="Latitude", y_label="Cloudiness")
#
# TypeError: cannot unpack non-iterable NoneType object

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
#
# ### Analysis
#
# 1. The impact of latitude on cloud cover is weak:
#
#     - In the Northern Hemisphere, although the slope is positive (0.13), indicating a slight increase in cloud cover with increasing latitude, this relationship is very weak.
#     - In the Southern Hemisphere, the slope is even smaller (0.05), almost negligible, suggesting that the influence of latitude on cloud cover is even less significant.
#
# 2. Very low correlation: The r-value for both the Northern and Southern Hemispheres are very low, 0.066 and 0.015 respectively, indicating that there is almost no linear correlation between latitude and cloud cover in either hemisphere.
#
# 3. High data dispersion: In both charts, scatter points are widely dispersed without any obvious trend, further demonstrating that there isn't a significant relationship between latitude and cloud cover.
#
# ### Conclusion
#
# Overall, these two charts indicate that whether in the Northern or Southern Hemisphere, the effect of latitude on cloud cover is very weak and nearly non-existent in terms of correlation. This suggests that cloud cover may be influenced by other more complex climatic factors and geographical features rather than just changes in latitude alone. When studying cloud distribution, more variables and factors should be considered instead of focusing solely on latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df['Lat'].values
y = northern_hemi_df['Wind Speed'].values
create_linear_regression_plot(x, y, x_label="Latitude", y_label="Wind Speed")

# %%
# Southern Hemisphere
x = southern_hemi_df['Lat'].values
y = southern_hemi_df['Wind Speed'].values
create_linear_regression_plot(x, y, x_label="Latitude", y_label="Wind Speed")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
#
# ### Analysis
#
# 1. The impact of latitude on wind speed is minimal:
#
#     - In the Northern Hemisphere, the slope is -0.01, indicating a slight decrease in wind speed with increasing latitude, but this relationship is very weak.
#     - In the Southern Hemisphere, the slope is -0.02, also indicating a slight decrease in wind speed with increasing latitude, but this relationship is similarly very weak.
#
# 2. Very low correlation: The r-value for both the Northern and Southern Hemispheres is approximately -0.106, suggesting that there is almost no linear correlation between latitude and wind speed in either hemisphere.
#
# 3. High data dispersion: In both charts, scatter points are widely dispersed without any clear trend, further illustrating that the relationship between latitude and wind speed is not significant.
#
# ### Conclusion
#
# Overall, these two charts indicate that whether in the Northern or Southern Hemisphere, the influence of latitude on wind speed is very minimal and almost non-existent. This suggests that wind speed may be influenced by other more complex climatic factors and geographical features rather than just changes in latitude. When studying wind speed distribution, more variables and factors should be considered instead of focusing solely on latitude.

# %% [markdown]
# ## Overall Conclusion
#
# Based on the analysis of the above four dimensions, the following conclusions are drawn:
#
# 1. Latitude has a significant impact on maximum temperature: There is a clear linear relationship between latitude in both hemispheres and maximum temperature, with higher temperatures near the equator and lower temperatures near the poles.
#
# 2. Latitude has a weak influence on humidity, cloud cover, and wind speed, with almost no significant linear relationship. This indicates that these meteorological factors are more influenced by other complex factors (such as local topography, oceanic effects, seasonal changes) rather than just changes in latitude.
#
# 3. Other influencing factors need to be considered:
#
#     - For variables such as humidity, cloud cover, and wind speed, local geographic and climatic conditions should be taken into account more when studying and predicting them. Future analyses can incorporate more meteorological and geographical data for a more comprehensive understanding of the relationships between these variables.
#
#     - Using more complex analytical models with multiple independent variables may provide more accurate prediction results.
